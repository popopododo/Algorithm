# %% [markdown]
# # Data Structure & Algorithm
# ## 자료구조과 알고리즘을 배우는 이유?
#
# ### -궁극적으로 어떤 자료구조나 알고리즘을 쓰냐에 따라 성능이 차이남 => 프로그래밍의 실력의 격차 생김

# %% [markdown]
# ## 자료구조란?
#
# ### 대량의 데이터를 효율적으로 관리할 수 있는 데이터의 구조
# #### ex) 배열,스택,큐, 링크드 리스트, 해쉬테이블, 힙 등

# %% [markdown]
# ## 알고리즘이란?
#
# ### 어떤 문제를 풀기 위한 절차/방법
#
# ## 자료구조를 활용하여 여러가지 알고리즘등을 사용해 문제를 풀이함
